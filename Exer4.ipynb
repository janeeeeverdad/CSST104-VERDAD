# %% [markdown]
# <a href="https://colab.research.google.com/github/janeeeeverdad/Verdad/blob/main/Exer4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CSST 104
#
# **Verdad, Jane Benneth Dione**
#
# **BSCS-3B**
#
# **February 27, 2024**

# %% [markdown]
# **SIMPLE LINEAR REGRESSION**

# %% [markdown]
# 1. Import Libraries

# %%
import pandas as pd #Data Manipulation
import numpy as np #Mathematical Operation
import matplotlib.pyplot as plt #Data Visualization
from sklearn.linear_model import LinearRegression #Data Modelling/Training Data

# %% [markdown]
# 2. Generating Random Data

# %%
num_points = 50
X = np.random.randint (0, 100, num_points)
Y = 2 * X + np.random.normal (0, 10, num_points)

# %% [markdown]
# 3. Create DataFrame and Saving to CSV:

# %%
data = pd.DataFrame ({'X' : X , 'Y' : Y})

data.to_csv('data.csv', index=False)
print(data.head())
# Out:
#     X           Y
# 0   0   12.771471
# 1  52  107.648997
# 2  21   34.549987
# 3  56   98.759991
# 4  49   96.362102

# %% [markdown]
# 4. Visualizing Data

# %%
plt.scatter(data['X'], data['Y'])
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (Y)')
plt.title('Scatter Plot of Data')
plt.show()

# %% [markdown]
# 5. Preparing Data for Modeling

# %%
X = data[['X']]
Y = data[['Y']]

# %% [markdown]
# 6. Fitting the Linear Regression Model

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# 7. Getting Model Coefficient

# %%
slope = model.coef_[0]
intercept = model.intercept_
print("Slope: ", slope)
print("Intercept: ", intercept)
# Out:
# Slope:  [2.10380432]
# Intercept:  [-5.72477884]

# %% [markdown]
# 8. Visualizing the Linear Regression Line

# %%
plt.scatter(X, Y)
plt.plot(X, model.predict(X), color= 'black')
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (Y)')
plt.title('Linear Regression')
plt.show()

# %% [markdown]
# 9. Making Predictions

# %%
new_X = [[np.random.randint(100, 200)]]
predicted_Y = model.predict(new_X)
print('Value of new X', new_X)
print('Predicted Y for new X: ', predicted_Y)
# Out:
# Value of new X [[171]]
# Predicted Y for new X:  [[354.02576032]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
